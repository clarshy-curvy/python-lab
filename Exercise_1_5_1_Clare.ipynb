# %%
# Task 1
marks = [10, 15, 10, 9, 18, 16, 14, 12, 16, 13, 15, 20, 17]

print("Original list:", marks)

marks.sort(reverse=True)

print("Descending Order:", marks)
# Out:
# Original list: [10, 15, 10, 9, 18, 16, 14, 12, 16, 13, 15, 20, 17]
# Descending Order: [20, 18, 17, 16, 16, 15, 15, 14, 13, 12, 10, 10, 9]
